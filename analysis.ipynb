# %%
import pandas as pd

# %%
fish = pd.read_csv("data.csv")

# %%
#| label: fish-table
fish
# Out:
#     Time (s)  Control  Increased Enzyme    HCl
# 0          0    0.138             0.142 -0.017
# 1         30    0.697             0.605  0.011
# 2         60    0.698             0.665  0.010
# 3         90    0.695             0.668  0.009
# 4        120    0.697             0.670  0.010
# 5        150    0.694             0.666  0.009
# 6        180    0.695             0.667  0.009
# 7        210    0.696             0.669  0.010
# 8        240    0.694             0.670  0.008
# 9        270    0.639             0.668  0.010
# 10       300    0.644             0.667  0.010

# %%
#| label: fish-histogram
fish.plot.hist(column=["Control", "HCl"], edgecolor='black');

# %%
#| label: fish-plot
fish.plot.line(x="Time (s)", y=["Control", "Increased Enzyme", "HCl"]);
